# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import KFold
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
# Out:
# 2024-07-01 20:39:18.506216: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-01 20:39:18.546667: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-01 20:39:19.272859: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import numpy as np
import pandas as pd
import cv2  # OpenCVライブラリ
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
import glob
import os
import sys
import pathlib
from pathlib import Path

# %%
current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)
sys.path.append(parent_dir)
current_file_path = pathlib.Path(os.getcwd())
parent_dir = current_file_path.parent

# %%
import fluid_intake_estimate
from fluid_intake_estimate import variable_data_set
from fluid_intake_estimate import attention
# Out:
# /home/s2/Desktop/washino/swallowing
# /home/s2/Desktop/washino/swallowing

# %%
directory_path = parent_dir / 'dataset'

# %%
names = ['washino', 'haruki', 'ezumi', 'hikaru', 'ibuki', 'kanata', 'kazuki', 'kishimoto', 'kosasayama', 'mocchi', 'nakaryo', 'ruku', 'shibata', 'soichiro', 'tsuji']
data = variable_data_set.VariableDataSet(786, scale=1, time_range = 70000)

count = 0

for name in names:    
    path = directory_path / name
    wav_files = glob.glob(os.path.join(path, '*.wav'))
    wav_file_count = len(wav_files)    
    
    csv_path = path / f'{name}.csv'    
    data.csv_to_dataset(path, csv_path, count, signal_processing='No')
    count += wav_file_count
    print(count)
# Out:
# 352
# 382
# 413
# 444
# 474
# 504
# 538
# 571
# 601
# 631
# 661
# 694
# 724
# 755
# 786

# %%
# 分割交差検証の設定
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# データを保持するためのリスト
train_data_splits_index = []
test_data_splits_index = []

# データのインデックスを分割
for train_index, test_index in kf.split(data.X):
    train_data_splits_index.append(train_index)
    test_data_splits_index.append(test_index)

# %%
y = []
predict = []

# %%
model = attention.SelfAttentionModel(scale = 1, time_range = 70000)

model_checkpoint = ModelCheckpoint(
    filepath='self_attention_20240701_model_best_0.keras',  # 保存するファイルのパス
    monitor='val_mean_absolute_error',        # 監視する値
    save_best_only=True,       # 最良のモデルのみを保存
    verbose=1,                 # 進行状況のメッセージ表示
    mode='min'                 # 「減少」を監視
)


use_data = 0
print(data.X.shape)
model.training(data.X[train_data_splits_index[use_data]], data.y[train_data_splits_index[use_data]], 15, 32)
model.evaluate(data.X[test_data_splits_index[use_data]], data.y[test_data_splits_index[use_data]])
model.save('self_attention_20240701_0.keras')
# Out:
# 2024-07-01 20:40:25.032509: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22052 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:65:00.0, compute capability: 8.6
# (786, 5000, 1)
# Epoch 1/15
# 2024-07-01 20:40:28.138185: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-07-01 20:40:38.222897: W tensorflow/tsl/framework/bfc_allocator.cc:485] Allocator (GPU_0_bfc) ran out of memory trying to allocate 5.96GiB (rounded to 6400000000)requested by op model/multi_head_attention_1/einsum/Einsum
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2024-07-01 20:40:38.222967: I tensorflow/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for GPU_0_bfc
# 2024-07-01 20:40:38.222990: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 121, Chunks in use: 120. 30.2KiB allocated for chunks. 30.0KiB in use in bin. 6.7KiB client-requested in use in bin.
# 2024-07-01 20:40:38.223005: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 9, Chunks in use: 9. 4.8KiB allocated for chunks. 4.8KiB in use in bin. 4.5KiB client-requested in use in bin.
# 2024-07-01 20:40:38.223018: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (1024): 	Total Chunks: 1, Chunks in use: 1. 1.2KiB allocated for chunks. 1.2KiB in use in bin. 1.0KiB client-requested in use in bin.
# 2024-07-01 20:40:38.223033: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (2048): 	Total Chunks: 25, Chunks in use: 25. 53.5KiB allocated for chunks. 53.5KiB in use in bin. 50.2KiB client-requested in use in bin.
# 2024-07-01 20:40:38.223046: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (4096): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-07-01 20:40:38.223060: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (8192): 	Total Chunks: 15, Chunks in use: 15. 120.0KiB allocated for chunks. 120.0KiB in use in bin. 120.0KiB client-requested in use in bin.
# 2024-07-01 20:40:38.223072: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (16384): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-07-01 20:40:38.223086: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (32768): 	Total Chunks: 3, Chunks in use: 3. 96.0KiB allocated for chunks. 96.0KiB in use in bin. 96.0KiB client-requested in use in bin.
# 2024-07-01 20:40:38.223097: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (65536): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-07-01 20:40:38.223108: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (131072): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-07-01 20:40:38.223122: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (262144): 	Total Chunks: 2, Chunks in use: 1. 635.0KiB allocated for chunks. 312.5KiB in use in bin. 312.5KiB client-requested in use in bin.
# 2024-07-01 20:40:38.223134: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (524288): 	Total Chunks: 5, Chunks in use: 5. 3.05MiB allocated for chunks. 3.05MiB in use in bin. 3.05MiB client-requested in use in bin.
# 2024-07-01 20:40:38.223146: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (1048576): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-07-01 20:40:38.223158: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (2097152): 	Total Chunks: 2, Chunks in use: 2. 4.88MiB allocated for chunks. 4.88MiB in use in bin. 4.88MiB client-requested in use in bin.
# 2024-07-01 20:40:38.223169: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (4194304): 	Total Chunks: 1, Chunks in use: 0. 4.88MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-07-01 20:40:38.223184: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (8388608): 	Total Chunks: 8, Chunks in use: 7. 79.14MiB allocated for chunks. 69.37MiB in use in bin. 69.37MiB client-requested in use in bin.
# 2024-07-01 20:40:38.223199: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (16777216): 	Total Chunks: 10, Chunks in use: 10. 192.87MiB allocated for chunks. 192.87MiB in use in bin. 185.55MiB client-requested in use in bin.
# 2024-07-01 20:40:38.223212: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-07-01 20:40:38.223225: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (67108864): 	Total Chunks: 1, Chunks in use: 1. 78.12MiB allocated for chunks. 78.12MiB in use in bin. 78.12MiB client-requested in use in bin.
# 2024-07-01 20:40:38.223244: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-07-01 20:40:38.223258: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (268435456): 	Total Chunks: 4, Chunks in use: 2. 21.18GiB allocated for chunks. 11.92GiB in use in bin. 11.92GiB client-requested in use in bin.
# 2024-07-01 20:40:38.223271: I tensorflow/tsl/framework/bfc_allocator.cc:1062] Bin for 5.96GiB was 256.00MiB, Chunk State:
# 2024-07-01 20:40:38.223288: I tensorflow/tsl/framework/bfc_allocator.cc:1068]   Size: 3.54GiB | Requested Size: 0B | in_use: 0 | bin_num: 20, prev:   Size: 5.96GiB | Requested Size: 5.96GiB | in_use: 1 | bin_num: -1
# 2024-07-01 20:40:38.223306: I tensorflow/tsl/framework/bfc_allocator.cc:1068]   Size: 5.72GiB | Requested Size: 0B | in_use: 0 | bin_num: 20, prev:   Size: 19.53MiB | Requested Size: 19.53MiB | in_use: 1 | bin_num: -1, next:   Size: 5.96GiB | Requested Size: 5.96GiB | in_use: 1 | bin_num: -1
# 2024-07-01 20:40:38.223316: I tensorflow/tsl/framework/bfc_allocator.cc:1075] Next region of size 23123591168
# 2024-07-01 20:40:38.223328: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7a5274000000 of size 1280 next 1
# 2024-07-01 20:40:38.223338: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7a5274000500 of size 256 next 2
# 2024-07-01 20:40:38.223347: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7a5274000600 of size 256 next 3
# 2024-07-01 20:40:38.223356: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7a5274000700 of size 256 next 5
# 2024-07-01 20:40:38.223365: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7a5274000800 of size 256 next 4
# 2024-07-01 20:40:38.223374: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7a5274000900 of size 256 next 6
# 2024-07-01 20:40:38.223383: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7a5274000a00 of size 256 next 7
# 2024-07-01 20:40:38.223392: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7a5274000b00 of size 256 next 8
# 2024-07-01 20:40:38.223401: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7a5274000c00 of size 256 next 9
# 2024-07-01 20:40:38.223410: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7a5274000d00 of size 256 next 12
# 2024-07-01 20:40:38.223419: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7a5274000e00 of size 256 next 14
# 2024-07-01 20:40:38.223428: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7a5274000f00 of size 256 next 13
# 2024-07-01 20:40:38.223437: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7a5274001000 of size 256 next 19
# 2024-07-01 20:40:38.223446: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7a5274001100 of size 256 next 15
# 2024-07-01 20:40:38.223455: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7a5274001200 of size 256 next 20
# 2024-07-01 20:40:38.223464: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7a5274001300 of size 256 next 25
# 2024-07-01 20:40:38.223473: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7a5274001400 of size 256 next 23
# 2024-07-01 20:40:38.223482: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7a5274001500 of size 256 next 24
# 2024-07-01 20:40:38.223491: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7a5274001600 of size 256 next 27
# 2024-07-01 20:40:38.223500: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7a5274001700 of size 256 next 28
# 2024-07-01 20:40:38.223509: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7a5274001800 of size 256 next 16
# 2024-07-01 20:40:38.223518: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7a5274001900 of size 2048 next 17
# 2024-07-01 20:40:38.223528: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7a5274002100 of size 2048 next 18
# 2024-07-01 20:40:38.223539: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7a5274002900 of size 512 next 31
# 2024-07-01 20:40:38.223549: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7a5274002b00 of size 256 next 34
# 2024-07-01 20:40:38.223558: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7a5274002c00 of size 256 next 29
# 2024-07-01 20:40:38.223567: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7a5274002d00 of size 256 next 30
# 2024-07-01 20:40:38.223576: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7a5274002e00 of size 256 next 59
# 2024-07-01 20:40:38.223585: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7a5
I tensorflow/tsl/framework/bfc_allocator.cc:1103] 5 Chunks of size 640000 totalling 3.05MiB
# 2024-07-01 20:40:38.225384: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 2560000 totalling 4.88MiB
# 2024-07-01 20:40:38.225395: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 6 Chunks of size 10240000 totalling 58.59MiB
# 2024-07-01 20:40:38.225406: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 11300096 totalling 10.78MiB
# 2024-07-01 20:40:38.225417: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 17920000 totalling 17.09MiB
# 2024-07-01 20:40:38.225428: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 9 Chunks of size 20480000 totalling 175.78MiB
# 2024-07-01 20:40:38.225439: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 81920000 totalling 78.12MiB
# 2024-07-01 20:40:38.225450: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 6400000000 totalling 11.92GiB
# 2024-07-01 20:40:38.225461: I tensorflow/tsl/framework/bfc_allocator.cc:1107] Sum Total of in-use chunks: 12.26GiB
# 2024-07-01 20:40:38.225472: I tensorflow/tsl/framework/bfc_allocator.cc:1109] Total bytes in pool: 23123591168 memory_limit_: 23123591168 available bytes: 0 curr_region_allocation_bytes_: 46247182336
# 2024-07-01 20:40:38.225488: I tensorflow/tsl/framework/bfc_allocator.cc:1114] Stats:
# Limit:                     23123591168
# InUse:                     13165852928
# MaxInUse:                  19325212160
# NumAllocs:                         315
# MaxAllocSize:               6440960000
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2024-07-01 20:40:38.225522: W tensorflow/tsl/framework/bfc_allocator.cc:497] **__________________________********************************************************________________
# 2024-07-01 20:40:38.225553: W tensorflow/core/framework/op_kernel.cc:1830] OP_REQUIRES failed at einsum_op_impl.h:603 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[32,2,5000,5000] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 2024-07-01 20:40:38.225595: I tensorflow/core/common_runtime/executor.cc:1197] [/job:localhost/replica:0/task:0/device:GPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[32,2,5000,5000] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node model/multi_head_attention_1/einsum/Einsum}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[9], line 14
#      12 use_data = 0
#      13 print(data.X.shape)
# ---> 14 model.training(data.X[train_data_splits_index[use_data]], data.y[train_data_splits_index[use_data]], 15, 32)
#      15 model.evaluate(data.X[test_data_splits_index[use_data]], data.y[test_data_splits_index[use_data]])
#      16 model.save('self_attention_20240701_0.keras')
#
# File ~/Desktop/washino/fluid_intake/fluid_intake_estimate/dence_net.py:23, in DenceNet.training(self, X_train, y_train, epochs, batch_size, early_stopping, model_checkpoint)
#      21 def training(self, X_train, y_train, epochs, batch_size, early_stopping = None, model_checkpoint = None):
#      22     if early_stopping == None and model_checkpoint == None:
# ---> 23         self.model.fit(X_train, y_train, epochs=epochs, validation_split=0.1, batch_size= batch_size)
#      24     elif early_stopping == None:
#      25         self.model.fit(X_train, y_train, epochs=epochs, validation_split=0.1, batch_size= batch_size, callbacks=[model_checkpoint])
#
# File ~/.conda/envs/washino/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/.conda/envs/washino/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node 'model/multi_head_attention_1/einsum/Einsum' defined at (most recent call last):
#     File "/home/s2/.conda/envs/washino/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/home/s2/.conda/envs/washino/lib/python3.10/runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "/home/s2/.conda/envs/washino/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/home/s2/.conda/envs/washino/lib/python3.10/site-packages/traitlets/config/application.py", line 992, in launch_instance
#       app.start()
#     File "/home/s2/.conda/envs/washino/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 736, in start
#       self.io_loop.start()
#     File "/home/s2/.conda/envs/washino/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 195, in start
#       self.asyncio_loop.run_forever()
#     File "/home/s2/.conda/envs/washino/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#       self._run_once()
#     File "/home/s2/.conda/envs/washino/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#       handle._run()
#     File "/home/s2/.conda/envs/washino/lib/python3.10/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/home/s2/.conda/envs/washino/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#       await self.process_one()
#     File "/home/s2/.conda/envs/washino/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#       await dispatch(*args)
#     File "/home/s2/.conda/envs/washino/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#       await result
#     File "/home/s2/.conda/envs/washino/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#       reply_content = await reply_content
#     File "/home/s2/.conda/envs/washino/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#       res = shell.run_cell(
#     File "/home/s2/.conda/envs/washino/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/home/s2/.conda/envs/washino/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3024, in run_cell
#       result = self._run_cell(
#     File "/home/s2/.conda/envs/washino/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3079, in _run_cell
#       result = runner(coro)
#     File "/home/s2/.conda/envs/washino/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/home/s2/.conda/envs/washino/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3284, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/home/s2/.conda/envs/washino/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3466, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/home/s2/.conda/envs/washino/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/tmp/ipykernel_32748/2743029873.py", line 14, in <module>
#       model.training(data.X[train_data_splits_index[use_data]], data.y[train_data_splits_index[use_data]], 15, 32)
#     File "/home/s2/Desktop/washino/fluid_intake/fluid_intake_estimate/dence_net.py", line 23, in training
#       self.model.fit(X_train, y_train, epochs=epochs, validation_split=0.1, batch_size= batch_size)
#     File "/home/s2/.conda/envs/washino/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/s2/.conda/envs/washino/lib/python3.10/site-packages/keras/engine/training.py", line 1685, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/home/s2/.conda/envs/washino/lib/python3.10/site-packages/keras/engine/training.py", line 1284, in train_function
#       return step_function(self, iterator)
#     File "/home/s2/.conda/envs/washino/lib/python3.10/site-packages/keras/engine/training.py", line 1268, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/home/s2/.conda/envs/washino/lib/python3.10/site-packages/keras/engine/training.py", line 1249, in run_step
#       outputs = model.train_step(data)
#     File "/home/s2/.conda/envs/washino/lib/python3.10/site-packages/keras/engine/training.py", line 1050, in train_step
#       y_pred = self(x, training=True)
#     File "/home/s2/.conda/envs/washino/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/s2/.conda/envs/washino/lib/python3.10/site-packages/keras/engine/training.py", line 558, in __call__
#       return super().__call__(*args, **kwargs)
#     File "/home/s2/.conda/envs/washino/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/s2/.conda/envs/washino/lib/python3.10/site-packages/keras/engine/base_layer.py", line 1145, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/home/s2/.conda/envs/washino/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/s2/.conda/envs/washino/lib/python3.10/site-packages/keras/engine/functional.py", line 512, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "/home/s2/.conda/envs/washino/lib/python3.10/site-packages/keras/engine/functional.py", line 669, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "/home/s2/.conda/envs/washino/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/s2/.conda/envs/washino/lib/python3.10/site-packages/keras/engine/base_layer.py", line 1145, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/home/s2/.conda/envs/washino/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/s2/.conda/envs/washino/lib/python3.10/site-packages/keras/layers/attention/multi_head_attention.py", line 598, in call
#       attention_output, attention_scores = self._compute_attention(
#     File "/home/s2/.conda/envs/washino/lib/python3.10/site-packages/keras/layers/attention/multi_head_attention.py", line 527, in _compute_attention
#       attention_scores = tf.einsum(self._dot_product_equation, key, query)
# Node: 'model/multi_head_attention_1/einsum/Einsum'
# OOM when allocating tensor with shape[32,2,5000,5000] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node model/multi_head_attention_1/einsum/Einsum}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_5896]
